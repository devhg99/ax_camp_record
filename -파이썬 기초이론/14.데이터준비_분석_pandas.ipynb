# %% [markdown]
# # 개요

# %% [markdown]
# - pandas (팬더스,판다스)
#   - pandas is a **fast**, powerful, flexible and **easy** to use open source **data analysis** and manipulation tool,
# built on top of the **Python programming language**.
#
# - 파이썬 진영에서 R에 대응하는 라이브러리
#   - pandas(분석) + sklearn(머신러닝) + statsmodels(통계) <-> R
#
# - 자료구조
#   - **Series** : 1차원
#     - 배열(데이터) + 인덱스
#   - **DataFrame** : 2차원
#     - 배열(데이터) + 인덱스 + 컬럼

# %% [markdown]
# - 작업
#   - 1단계 raw데이터 획득
#     - 파일, 디비, ... (리소스로부터)
#     - DataFrame 생성
#   - 2단계 (아래 내용은 우선순위 없음)
#     - 데이터 전처리
#       - 정제, 클리닝 => 피처 엔지니어링
#     - 데이터 추출
#       - 원하는 데이터만 추출
#     - 데이터 병합(통합, 합치기)
#     - 집계, 피벗 => 기준이 범주형 데이터 => 인사이트 발견됨(숨겨진 의미를 찾을수 있음)
#     - .....
#   - 3단계 eda 시각화
#     - 2단계에서 필요시 도입 할 수 있음
#     - 파이썬 -> 정적, 일부동작
#       - matplotlib, seaborn, ...
#     - JS -> 인터렉티브
#       - d3, js, ...
#     - eda
#       - 데이터 분석
#       - 머신러닝/딥러닝 모델 학습시 데이터 적절한지 검토 활용

# %% [markdown]
# # 모듈 가져오기

# %%
import numpy as np
import pandas as pd

# 2.2.2
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# # 자료구조

# %% [markdown]
# - Series
#   - 1차원
#   - 구성
#     - Series = ndarray(데이터,1차원) + 인덱스
#
# - DataFrame
#   - 2차원
#   - 구성
#     - DataFrame = ndarray(데이터,1차원) + 인덱스 + 컬럼

# %% [markdown]
# ## Series

# %%
# 더미 데이터
# np.nan : Not a Number, 결측치
data = [-1, 3, 5, np.nan, 7, 8]
data
# Out:
# [-1, 3, 5, nan, 7, 8]

# %%
# 기본 생성
vec = pd.Series(data)
'''
- 왼쪽 : 0~5, 자동부여(별도 지정 없으면) => 인덱스
- 오른쪽 : 데이터
- 위쪽 : 0 -> 이름, 지정한게 없어서 0으로 표기
- 타입 : float64. 단일타입
'''
vec
# Out:
# 0   -1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    7.0
# 5    8.0
# dtype: float64

# %%
# numpy를 생각하고 기능 사용 => 대부분 존재함
vec.dtype

vec.name = '더미데이터'
vec
# Out:
# 0   -1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    7.0
# 5    8.0
# Name: 더미데이터, dtype: float64

# %%
# 기본 체크
vec, vec.dtype, vec.shape, vec.size, vec.name
# Out:
# (0   -1.0
#  1    3.0
#  2    5.0
#  3    NaN
#  4    7.0
#  5    8.0
#  Name: 더미데이터, dtype: float64,
#  dtype('float64'),
#  (6,),
#  6,
#  '더미데이터')

# %%
# 기초 통계량 확인 -> 수치 데이터만 해당됨
# 문자열 데이터는 누락시킴
vec.describe()
# Out:
# count    5.000000
# mean     4.400000
# std      3.577709
# min     -1.000000
# 25%      3.000000
# 50%      5.000000
# 75%      7.000000
# max      8.000000
# Name: 더미데이터, dtype: float64

# %%
# 분리
# 데이터만 추출 -> 배열
type(vec.values), vec.values
# Out:
# (numpy.ndarray, array([-1.,  3.,  5., nan,  7.,  8.]))

# %%
# 인덱스
vec.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# ## DataFrame

# %% [markdown]
# - 특징
#   - 동일한 크기(m)을 가진 Series n개를 모으면, 데이터프레임 구성 가능
#     - (m, n) : shape
#   - 데이터만 있어도 구성 가능

# %%
# 컬럼 데이터 구성
cols = list('ABCD')
cols
# Out:
# ['A', 'B', 'C', 'D']

# %%
# 인덱스 데이터 구성
indexs = pd.date_range(start='20250410', periods=7)
indexs
# Out:
# DatetimeIndex(['2025-04-10', '2025-04-11', '2025-04-12', '2025-04-13',
#                '2025-04-14', '2025-04-15', '2025-04-16'],
#               dtype='datetime64[ns]', freq='D')

# %%
len(indexs), len(cols)
# Out:
# (7, 4)

# %%
# 더미데이터 구성
values = np.random.randn(len(indexs), len(cols)) # (7,4)
values
# Out:
# array([[ 0.27292125, -1.56510652, -1.39967363, -0.35989097],
#        [ 0.81106363,  1.72815103,  0.56867028,  0.86237712],
#        [ 0.94767552, -0.57410468,  0.47739868, -1.08372784],
#        [-0.89101922, -0.16801599, -0.99324755, -1.31511747],
#        [-1.97579791, -0.20163865,  0.07784691,  0.98327   ],
#        [ 0.35570641, -1.52711546, -0.78685068,  0.1861155 ],
#        [ 0.33042753,  1.00613291, -0.86121823,  2.52659115]])

# %%
# DataFrame 생성
df=pd.DataFrame(data=values,index=indexs,columns=cols)
df
# Out:
#                    A         B         C         D
# 2025-04-10  0.272921 -1.565107 -1.399674 -0.359891
# 2025-04-11  0.811064  1.728151  0.568670  0.862377
# 2025-04-12  0.947676 -0.574105  0.477399 -1.083728
# 2025-04-13 -0.891019 -0.168016 -0.993248 -1.315117
# 2025-04-14 -1.975798 -0.201639  0.077847  0.983270
# 2025-04-15  0.355706 -1.527115 -0.786851  0.186115
# 2025-04-16  0.330428  1.006133 -0.861218  2.526591

# %%
# 데이터 경로
# '/content/drive/MyDrive/2. 데이터분석/res/customer_master.csv'

# csv(raw data, 이커머스에서 고객 마스터 데이터) -> df
source_path = '/content/drive/MyDrive/2. 데이터분석/data/customer_master.csv'
customer_master = pd.read_csv(source_path)

# 상위값 5개 출력 : head(), head(커스텀개수 지정가능)
customer_master.head()
# Out:
#   customer_id customer_name registration_date                        email  \
# 0    IK152942           김서준   2019-01-01 0:25  hirata_yuujirou@example.com
# 1    TS808488           김예준   2019-01-01 1:13    tamura_shiori@example.com
# 2    AS834628           김도윤   2019-01-01 2:00      hisano_yuki@example.com
# 3    AS345469           김시우   2019-01-01 4:48   tsuruoka_kaoru@example.com
# 4    GD892565           김주원   2019-01-01 4:54   oouchi_takashi@example.com
#
#   gender  age       birth   pref
# 0      M   29  1990-06-10  대전광역시
# 1      F   33  1986-05-20  인천광역시
# 2      F   63  1956-01-02  광주광역시
# 3      M   74  1945-03-25  인천광역시
# 4      M   54  1965-08-05  울산광역시

# %% [markdown]
# # 기초 점검

# %% [markdown]
# - 데이터 이해 -> 통찰(데이터 분석 목적)을 얻는 행위
#   - 데이터는 무엇을 설명하는 것인가?

# %%
# df 로드되면 1순위 체크
# 데이터는 5천개, 컬럼 8개(데이터 1개는 8개의 특징으로 묘사된다)
customer_master.shape

'''
- 컬럼
  - 머신러닝에서는 특성, feature. label/정답/class
  - 통계에서는       독립변수,     종속변수
'''
# Out:
# '\n- 컬럼\n  - 머신러닝에서는 특성, feature. label/정답/class\n  - 통계에서는       독립변수,     종속변수\n'

# %%
# 상위값 체크 1개
customer_master.head(2)
# Out:
#   customer_id customer_name registration_date                        email  \
# 0    IK152942           김서준   2019-01-01 0:25  hirata_yuujirou@example.com
# 1    TS808488           김예준   2019-01-01 1:13    tamura_shiori@example.com
#
#   gender  age       birth   pref
# 0      M   29  1990-06-10  대전광역시
# 1      F   33  1986-05-20  인천광역시

# %%
# 하위값 체크 1개
customer_master.tail(1)
# Out:
#      customer_id customer_name registration_date                    email  \
# 4999    HI349563           정지석  2019-07-31 22:49  horii_kanji@example.com
#
#      gender  age       birth   pref
# 4999      M   21  1998-02-06  서울특별시

# %%
# 무작위 샘플링값 체크 5개
customer_master.sample(5)
# Out:
#      customer_id customer_name registration_date  \
# 3452    GD885447           최승율  2019-05-26 21:42
# 2665    GD296025           박성찬  2019-04-23 19:56
# 743     PL983619           김강산   2019-02-04 4:44
# 1475    PL229628           이혜린   2019-03-05 4:34
# 543     HI737185           김시혁  2019-01-26 21:47
#
#                               email gender  age       birth   pref
# 3452    takeuchi_shidou@example.com      M   39  1980-06-21  대전광역시
# 2665      yaguchi_meibi@example.com      F   72  1946-09-26  울산광역시
# 743         sawa_hikaru@example.com      F   24  1995-07-08  대전광역시
# 1475  nagatomo_chinatsu@example.com      F   38  1980-08-15  서울특별시
# 543         arita_yuuko@example.com      F   24  1994-12-27  대전광역시

# %%
# 타입 확인(컬럼별로 상이, 컬럼내에서는 동일)
customer_master.dtypes

# 나이를 제외하고는 모두 객체 => 문자열로 예상된다
# 나이 => 세대 구성 => 고객 분류 => 고객별 마케팅 재료
# Out:
# customer_id          object
# customer_name        object
# registration_date    object
# email                object
# gender               object
# age                   int64
# birth                object
# pref                 object
# dtype: object

# %%
# 컬럼이 많은 경우 => 표현이 다 안됨 => T 검토 (피처 요약표본)
customer_master.dtypes # Series
# Out:
# customer_id          object
# customer_name        object
# registration_date    object
# email                object
# gender               object
# age                   int64
# birth                object
# pref                 object
# dtype: object

# %%
# 성분 추출
# 컬럼 정보 추출
customer_master.columns
# Out:
# Index(['customer_id', 'customer_name', 'registration_date', 'email', 'gender',
#        'age', 'birth', 'pref'],
#       dtype='object')

# %%
# 인덱스, 값 각각 출력 (생략)
customer_master.index, customer_master.values
# Out:
# (RangeIndex(start=0, stop=5000, step=1),
#  array([['IK152942', '김서준', '2019-01-01 0:25', ..., 29, '1990-06-10',
#          '대전광역시'],
#         ['TS808488', '김예준', '2019-01-01 1:13', ..., 33, '1986-05-20',
#          '인천광역시'],
#         ['AS834628', '김도윤', '2019-01-01 2:00', ..., 63, '1956-01-02',
#          '광주광역시'],
#         ...,
#         ['PL538517', '정준기', '2019-07-31 19:30', ..., 73, '1945-12-28',
#          '대전광역시'],
#         ['OA955088', '정도형', '2019-07-31 22:32', ..., 75, '1944-04-09',
#          '부산광역시'],
#         ['HI349563', '정지석', '2019-07-31 22:49', ..., 21, '1998-02-06',
#          '서울특별시']], dtype=object))

# %%
# 결측검사
customer_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        5000 non-null   object
#  1   customer_name      5000 non-null   object
#  2   registration_date  5000 non-null   object
#  3   email              5000 non-null   object
#  4   gender             5000 non-null   object
#  5   age                5000 non-null   int64
#  6   birth              5000 non-null   object
#  7   pref               5000 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 312.6+ KB

# %%
# db.컬럼명 => 해당데이터만 추출 가능함
# 컬럼명은 자동으로 db의 속성으로 추가 -> 단, 컬럼명에 공백이 존재하면 생성 x
customer_master.age
# Out:
# 0       29
# 1       33
# 2       63
# 3       74
# 4       54
#         ..
# 4995    77
# 4996    27
# 4997    73
# 4998    75
# 4999    21
# Name: age, Length: 5000, dtype: int64

# %%
# 기초 통계 확인 -> 수치만 정리가 됨
customer_master.describe()
# Out:
#                age
# count  5000.000000
# mean     50.053200
# std      17.338607
# min      20.000000
# 25%      35.000000
# 50%      50.000000
# 75%      65.000000
# max      80.000000

# %%
# age 컬럼 데이터를 가진 정렬(sort)해서 확인
# 고객은 20~80 분포
# 20대, 30대, 40대, ...  연령대별 군집 => 분석
customer_master.sort_values(by='age', ascending=True)
# Out:
#      customer_id customer_name registration_date  \
# 3509    AS347661           최승균  2019-05-29 16:29
# 1432    OA912932           이예빈   2019-03-03 8:37
# 3597    HI652401           최민창  2019-06-02 14:14
# 3531    PL248170           최의성  2019-05-30 15:31
# 3483    HI181798           최주승  2019-05-28 17:39
# ...          ...           ...               ...
# 926     GD595676           김은상   2019-02-12 0:13
# 3384    HD117235           최소율  2019-05-23 23:04
# 3323    HD771279            최온   2019-05-22 2:34
# 3536    GD748823           최한민  2019-05-30 21:15
# 1071    TS598952           김승표   2019-02-17 8:51
#
#                                email gender  age       birth   pref
# 3509      inui_masatoshi@example.com      M   20  1999-05-19  부산광역시
# 1432       kanaya_satomi@example.com      F   20  1998-09-05  울산광역시
# 3597       hisano_sachie@example.com      F   20  1998-11-30  서울특별시
# 3531         sakurai_yuu@example.com      F   20  1999-01-14  부산광역시
# 3483      miyagi_yoshino@example.com      F   20  1999-07-20  대전광역시
# ...                              ...    ...  ...         ...    ...
# 926       hamano_stmaria@example.com      F   80  1938-10-16  서울특별시
# 3384       kuroiwa_kouji@example.com      M   80  1939-05-08  서울특별시
# 3323   kitayama_kazuhisa@example.com      M   80  1939-04-25  인천광역시
# 3536      shiozawa_keiji@example.com      M   80  1938-10-16  인천광역시
# 1071  kurokawa_hidetsugu@example.com      M   80  1938-10-19  서울특별시
#
# [5000 rows x 8 columns]

# %% [markdown]
# # 데이터 추출

# %% [markdown]
# - df에서 원하는대로 데이터를 추출할 수 있어야 한다

# %% [markdown]
# ### 기본 인덱싱

# %% [markdown]
# - 차원축소
#   - DataFrame -> 인덱싱 -> Series -> 인덱싱 -> value
#   - 매트릭스 -> 인덱싱 -> 백터 -> 인덱싱 -> 스칼라\
#   - 2차원 -> 인덱싱 -> 1차원 -> 인덱싱 -> 0차원
#
# - 특징
#   - 데이터를 특정하는 요소 인덱스, 컬럼중 **기본인덱싱**은 **컬럼**을 기반

# %% [markdown]
# #### 차원축소

# %%
# 컬럼명 적용
data = customer_master['age']

# DF -> Series
type(data), data
# Out:
# (pandas.core.series.Series,
#  0       29
#  1       33
#  2       63
#  3       74
#  4       54
#          ..
#  4995    77
#  4996    27
#  4997    73
#  4998    75
#  4999    21
#  Name: age, Length: 5000, dtype: int64)

# %%
# 컬럼명에 공백이 내부나 등등 존재하면 아래처럼 표현 x
# 변수 ['컬럼 명] <= 이렇게만 사용 or 컬럼명 변경후 사용
customer_master.age
# Out:
# 0       29
# 1       33
# 2       63
# 3       74
# 4       54
#         ..
# 4995    77
# 4996    27
# 4997    73
# 4998    75
# 4999    21
# Name: age, Length: 5000, dtype: int64

# %% [markdown]
# #### 차원유지

# %%
# age 컬럼만 보고 싶은데, 차원은 유지하고 싶다(df로 보고 싶다)
# df[['컬럼명']]
age_df = customer_master[['age']]
age_df.shape, type(age_df)
# Out:
# ((5000, 1), pandas.core.frame.DataFrame)

# %% [markdown]
# #### 특정 컬럼만 추출

# %%
# 모든 컬럼 확인
# 데이터를 잘 설명하는 문구인지 확인, 컬럼명에 공백이 있는지 확인
# 필요시 조정, 개별 수정, 전체 일괄 수정 가능함 > 함수사용
customer_master.columns
# Out:
# Index(['customer_id', 'customer_name', 'registration_date', 'email', 'gender',
#        'age', 'birth', 'pref'],
#       dtype='object')

# %%
# 원본 데이터에서 특정 컬럼만 배치하여 데이터 추출 가능
customer_master[['customer_name','gender','age','registration_date']]
# Out:
#      customer_name gender  age registration_date
# 0              김서준      M   29   2019-01-01 0:25
# 1              김예준      F   33   2019-01-01 1:13
# 2              김도윤      F   63   2019-01-01 2:00
# 3              김시우      M   74   2019-01-01 4:48
# 4              김주원      M   54   2019-01-01 4:54
# ...            ...    ...  ...               ...
# 4995           정우석      F   77  2019-07-31 16:52
# 4996           정영훈      F   27  2019-07-31 19:09
# 4997           정준기      F   73  2019-07-31 19:30
# 4998           정도형      F   75  2019-07-31 22:32
# 4999           정지석      M   21  2019-07-31 22:49
#
# [5000 rows x 4 columns]

# %% [markdown]
# #### 인덱스 데이터로 인덱싱을 한다면?

# %%
# 해당 되는 키가 없다 => 그런 컬럼은 없다
# 에러 발생
# customer_master[1]

# %% [markdown]
# ### 기본 슬라이싱

# %% [markdown]
# - 차원 유지
# - df[시작인덱스:끝인덱스:step]

# %%
customer_master.head()
# Out:
#   customer_id customer_name registration_date                        email  \
# 0    IK152942           김서준   2019-01-01 0:25  hirata_yuujirou@example.com
# 1    TS808488           김예준   2019-01-01 1:13    tamura_shiori@example.com
# 2    AS834628           김도윤   2019-01-01 2:00      hisano_yuki@example.com
# 3    AS345469           김시우   2019-01-01 4:48   tsuruoka_kaoru@example.com
# 4    GD892565           김주원   2019-01-01 4:54   oouchi_takashi@example.com
#
#   gender  age       birth   pref
# 0      M   29  1990-06-10  대전광역시
# 1      F   33  1986-05-20  인천광역시
# 2      F   63  1956-01-02  광주광역시
# 3      M   74  1945-03-25  인천광역시
# 4      M   54  1965-08-05  울산광역시

# %%
# 기본 슬라이스 적용
# 1,3 이라는 표현 순번을 말하는것인지? 인덱스 값?
# 인덱스, 컬럼은 잠재적으로 0,1,2, 순서를 가지고 있다
customer_master[1:3]
# Out:
#   customer_id customer_name registration_date                      email  \
# 1    TS808488           김예준   2019-01-01 1:13  tamura_shiori@example.com
# 2    AS834628           김도윤   2019-01-01 2:00    hisano_yuki@example.com
#
#   gender  age       birth   pref
# 1      F   33  1986-05-20  인천광역시
# 2      F   63  1956-01-02  광주광역시

# %%
# step 적용
customer_master[1:10:2]
# Out:
#   customer_id customer_name registration_date                       email  \
# 1    TS808488           김예준   2019-01-01 1:13   tamura_shiori@example.com
# 3    AS345469           김시우   2019-01-01 4:48  tsuruoka_kaoru@example.com
# 5    AS265381           김하준   2019-01-01 5:51   kasai_yousuke@example.com
# 7    HI791416           김지후   2019-01-01 7:03    hosoi_mayuko@example.com
# 9    OA239766           김준우   2019-01-01 8:59   tamaki_yukiya@example.com
#
#   gender  age       birth   pref
# 1      F   33  1986-05-20  인천광역시
# 3      M   74  1945-03-25  인천광역시
# 5      M   69  1949-08-09  서울특별시
# 7      F   30  1989-07-25  대구광역시
# 9      M   22  1997-01-12  인천광역시

# %% [markdown]
# ### 인덱스 수정

# %%
index_count = len(customer_master.index)
index_count
# Out:
# 5000

# %%
date_index = pd.date_range(start='20100101', periods=index_count)
date_index
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2023-08-31', '2023-09-01', '2023-09-02', '2023-09-03',
#                '2023-09-04', '2023-09-05', '2023-09-06', '2023-09-07',
#                '2023-09-08', '2023-09-09'],
#               dtype='datetime64[ns]', length=5000, freq='D')

# %%
# 복사본
df = customer_master.copy(deep=True) # [:] # 처음부터 끝까지
df.index = date_index # 인덱스 교체
df.head(2)
# Out:
#            customer_id customer_name registration_date  \
# 2010-01-01    IK152942           김서준   2019-01-01 0:25
# 2010-01-02    TS808488           김예준   2019-01-01 1:13
#
#                                   email gender  age       birth   pref
# 2010-01-01  hirata_yuujirou@example.com      M   29  1990-06-10  대전광역시
# 2010-01-02    tamura_shiori@example.com      F   33  1986-05-20  인천광역시

# %%
# 1,3은 암묵적으로 적용되는 순번(인덱스, 0, 1, 2, ...)
# 인덱스, 값을 사용하는 것x
# 명시적 인덱스 값(2012-01-02) 사용하는것 => loc[]
# 암묵적 인덱스 값(0,1,2,..) 사용하는것 => iloc[]
df[1:3]
# Out:
#            customer_id customer_name registration_date  \
# 2010-01-02    TS808488           김예준   2019-01-01 1:13
# 2010-01-03    AS834628           김도윤   2019-01-01 2:00
#
#                                 email gender  age       birth   pref
# 2010-01-02  tamura_shiori@example.com      F   33  1986-05-20  인천광역시
# 2010-01-03    hisano_yuki@example.com      F   63  1956-01-02  광주광역시

# %% [markdown]
# ### loc

# %% [markdown]
# - location 위치 정보를 이용하여 특정, 추출
#   - 컬럼 값, 인덱스 값 사용
# - 데이터 2차원
#   - 2차원 좌표계로 표현(인덱스값,컬럼값)

# %% [markdown]
# #### 인덱스값 중심 표현

# %%
# df.loc['인덱스값']
res = df.loc[ '20100410' ] # 인덱싱 -> 차원축소 -> 시리즈

type(res), res
# Out:
# (pandas.core.series.Series,
#  customer_id                         PL683089
#  customer_name                            김태준
#  registration_date           2019-01-05 14:06
#  email                kagawa_miki@example.com
#  gender                                     F
#  age                                       28
#  birth                             1991-06-14
#  pref                                   광주광역시
#  Name: 2010-04-10 00:00:00, dtype: object)

# %%
# 슬라이싱 -> 차원유지
# 시작값 <= 데이터 <= 끝값(포함됨)
df.loc[ '20100410':'20250413' ]
# Out:
#            customer_id customer_name registration_date  \
# 2010-04-10    PL683089           김태준  2019-01-05 14:06
# 2010-04-11    HI024535           김승호  2019-01-05 15:10
# 2010-04-12    HI026312           김성빈  2019-01-05 16:30
# 2010-04-13    OA510950           김주호  2019-01-05 18:40
# 2010-04-14    PL924048           김민서  2019-01-05 18:47
# ...                ...           ...               ...
# 2023-09-05    AS677229           정우석  2019-07-31 16:52
# 2023-09-06    HD758694           정영훈  2019-07-31 19:09
# 2023-09-07    PL538517           정준기  2019-07-31 19:30
# 2023-09-08    OA955088           정도형  2019-07-31 22:32
# 2023-09-09    HI349563           정지석  2019-07-31 22:49
#
#                                    email gender  age       birth   pref
# 2010-04-10       kagawa_miki@example.com      F   28  1991-06-14  광주광역시
# 2010-04-11    kaneko_mayuko1@example.com      F   45  1974-05-28  부산광역시
# 2010-04-12  matsushima_kanji@example.com      M   60  1959-08-04  서울특별시
# 2010-04-13     momose_tamaki@example.com      F   59  1960-02-01  대구광역시
# 2010-04-14     kozaka_sachie@example.com      F   64  1955-04-23  울산광역시
# ...                                  ...    ...  ...         ...    ...
# 2023-09-05     hirayama_risa@example.com      F   77  1941-10-17  대전광역시
# 2023-09-06   nakahara_mahiru@example.com      F   27  1991-11-13  광주광역시
# 2023-09-07       tabata_yuu1@example.com      F   73  1945-12-28  대전광역시
# 2023-09-08   setouchi_hikaru@example.com      F   75  1944-04-09  부산광역시
# 2023-09-09       horii_kanji@example.com      M   21  1998-02-06  서울특별시
#
# [4901 rows x 8 columns]

# %%
res = df.loc[ ['20100410'] ] # 차원유지

# %% [markdown]
# #### 인덱스, 컬럼 조합 표현(좌표)

# %%
# 인덱스 -> 인덱싱, 컬럼 -> 인덱싱 => 차원축소 2회 => 스칼라
df.loc['20100410','customer_name']
# Out:
# '김태준'

# %%
# 차원축소 1회
df.loc['20100410',['customer_name']]
# Out:
# customer_name    김태준
# Name: 2010-04-10 00:00:00, dtype: object

# %%
# 차원축소 1회
df.loc[['20100410'],'customer_name']
# Out:
# 2010-04-10    김태준
# Name: customer_name, dtype: object

# %%
# 차원유지
df.loc[['20100410'],['customer_name']]
# Out:
#            customer_name
# 2010-04-10           김태준

# %% [markdown]
# #### 인덱스, 컬럼 조합 2

# %%
# 슬라이싱, 인덱싱 조함
# 해당 날짜에 해당되는 데이터중에서 고객명만 추출하시오
tmp = df.loc['20100410':'20100415',['customer_name']]
tmp
# Out:
#            customer_name
# 2010-04-10           김태준
# 2010-04-11           김승호
# 2010-04-12           김성빈
# 2010-04-13           김주호
# 2010-04-14           김민서
# 2010-04-15           김도영

# %%
# 실습 : 위와 같은 날짜에서 이름, 나이를 추출하시오 : (6:2)
# 1차원 슬라이싱, 2차원은 열고(순서를 변경)
df.loc['20100410':'20100415',['customer_name','age']]
# Out:
#            customer_name  age
# 2010-04-10           김태준   28
# 2010-04-11           김승호   45
# 2010-04-12           김성빈   60
# 2010-04-13           김주호   59
# 2010-04-14           김민서   64
# 2010-04-15           김도영   33

# %%
# 1차원 슬라이싱, 2차원 슬라이싱
df.loc['20100410':'20100415','customer_name':'age']
# Out:
#            customer_name registration_date                         email  \
# 2010-04-10           김태준  2019-01-05 14:06       kagawa_miki@example.com
# 2010-04-11           김승호  2019-01-05 15:10    kaneko_mayuko1@example.com
# 2010-04-12           김성빈  2019-01-05 16:30  matsushima_kanji@example.com
# 2010-04-13           김주호  2019-01-05 18:40     momose_tamaki@example.com
# 2010-04-14           김민서  2019-01-05 18:47     kozaka_sachie@example.com
# 2010-04-15           김도영  2019-01-05 20:17  miyamoto_stmaria@example.com
#
#            gender  age
# 2010-04-10      F   28
# 2010-04-11      F   45
# 2010-04-12      M   60
# 2010-04-13      F   59
# 2010-04-14      F   64
# 2010-04-15      F   33

# %% [markdown]
# #### 조건식 결합
#
# - 백터(혹은 1차원, 혹은 Series)등 형태로 True or False가 세팅된 배열/시리즈등이 조건자리로 위치
# - 포함되는 데이터와, 배제되는 데이터로 나뉘게 된다
# - 포함되는 데이터만 추출

# %%
# 5천명의 고객중 4152명이 연령 30세 초과(>)
df[df.age > 30].shape, df.loc[df.age > 30].shape
# Out:
# ((4152, 8), (4152, 8))

# %%
# df에서 email 데이터를 제외한 나머지 데이터만 추출 -> shape 확인
# 실습, drop 함수도 별도로 존재함
df.loc[ : , df.columns != 'email'].shape
# Out:
# (5000, 7)

# %%
# 람다 함수 활용 -> 블린을 반환하는 함수
df.loc[lambda df:df['age']==29].shape
# Out:
# (76, 8)

# %% [markdown]
# ### iloc

# %% [markdown]
# - index location
#   - 암묵적으로 존재하는 인덱스 값 활용
#   - 순번(순서)등을 이용하여 추출 -> 실제적 좌표

# %%
# df.iloc[인덱스위치의 암묵적인 순번]
df.iloc[0] # 0 : 첫번째 데이터
# Out:
# customer_id                             IK152942
# customer_name                                김서준
# registration_date                2019-01-01 0:25
# email                hirata_yuujirou@example.com
# gender                                         M
# age                                           29
# birth                                 1990-06-10
# pref                                       대전광역시
# Name: 2010-01-01 00:00:00, dtype: object

# %%
df.iloc[:,:].shape
# Out:
# (5000, 8)

# %%
# 인덱스이므로, 우측 경계 포함x
df.iloc[1:3,1:3].shape
# Out:
# (2, 2)

# %%
# 팬시 인덱싱 유사
# 원하는 데이터, 원하는 컬럼을 원하는 순서대로 배치
df.iloc[[1,10,4],[4,2,6]]
# Out:
#            gender registration_date       birth
# 2010-01-02      F   2019-01-01 1:13  1986-05-20
# 2010-01-11      M  2019-01-01 15:13  1967-11-08
# 2010-01-05      M   2019-01-01 4:54  1965-08-05

# %%
df.columns
# Out:
# Index(['customer_id', 'customer_name', 'registration_date', 'email', 'gender',
#        'age', 'birth', 'pref'],
#       dtype='object')

# %% [markdown]
# - 기타 대부분 표현 방식은 loc와 유

# %% [markdown]
# ### 블리언인덱싱

# %% [markdown]
# - customer_newer.csv 로드
# - cus라는 변수명의 df를 구성

# %%
# 데이터 로드

cus = pd.read_csv('/content/drive/MyDrive/2. 데이터분석/data/customer_newer.csv')

cus.head(4)
# Out:
#   customer_id   name class gender  start_date end_date campaign_id  \
# 0    OA832399   XXXX   C01      F  2015-05-01      NaN         CA1
# 1    PL270116  XXXXX   C01      M  2015-05-01      NaN         CA1
# 2    OA974876  XXXXX   C01      M  2015-05-01      NaN         CA1
# 3    HD024127  XXXXX   C01      F  2015-05-01      NaN         CA1
#
#    is_deleted class_name  price campaign_name      mean  median  max  min  \
# 0           0       0_종일  10500          2_일반  4.833333     5.0    8    2
# 1           0       0_종일  10500          2_일반  5.083333     5.0    7    3
# 2           0       0_종일  10500          2_일반  4.583333     5.0    6    3
# 3           0       0_종일  10500          2_일반  4.833333     4.5    7    2
#
#    routine_flg   calc_date  membership_period
# 0            1  2019-04-30                 47
# 1            1  2019-04-30                 47
# 2            1  2019-04-30                 47
# 3            1  2019-04-30                 47

# %%
# 데이터 2953, 컬럼 18개
cus.shape
# Out:
# (2953, 18)

# %%
# 기본 분석
# is_deleted => 탈퇴여부
cus.is_deleted.value_counts() #값의 개수를 카운트 함수
# (특정 컬럼의 집계후 카운트 처리)

# 111명이 탈퇴, 현재 실 고객수는 2842명
# Out:
# is_deleted
# 0    2842
# 1     111
# Name: count, dtype: int64

# %%
# 탈퇴하지 않는(현재 이용 고객) 고객들 정보만 tmp 변수로 모으시오
tmp = cus[cus.is_deleted == 0]

tmp.info()

# end_date 컬럼만 결측 => 실제 이용고객만 획듯
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2842 entries, 0 to 2952
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_id        2842 non-null   object
#  1   name               2842 non-null   object
#  2   class              2842 non-null   object
#  3   gender             2842 non-null   object
#  4   start_date         2842 non-null   object
#  5   end_date           0 non-null      object
#  6   campaign_id        2842 non-null   object
#  7   is_deleted         2842 non-null   int64
#  8   class_name         2842 non-null   object
#  9   price              2842 non-null   int64
#  10  campaign_name      2842 non-null   object
#  11  mean               2842 non-null   float64
#  12  median             2842 non-null   float64
#  13  max                2842 non-null   int64
#  14  min                2842 non-null   int64
#  15  routine_flg        2842 non-null   int64
#  16  calc_date          2842 non-null   object
#  17  membership_period  2842 non-null   int64
# dtypes: float64(2), int64(6), object(10)
# memory usage: 421.9+ KB

# %%
# 조건 1개
# 회원들중에 남성 혹은 여성 회원만 추출하시오 : 실습
cus.gender.value_counts()
# Out:
# gender
# M    1553
# F    1400
# Name: count, dtype: int64

# %%
# 해당 컬럼을 구성하는 모든데이터 보여줌
cus.gender.unique()
# 이 컬럼 데이터는 범주형 데이터로 간주 -> 집계, 피벅의 대상이됨
# Out:
# array(['F', 'M'], dtype=object)

# %%
# 회원들중에 남성 혹은 여성 회원만 추출하시오
cus[cus.gender == 'F']

display(res.head(2)), res.shape
# Out:
#            customer_id customer_name registration_date  \
# 2010-04-10    PL683089           김태준  2019-01-05 14:06
#
#                               email gender  age       birth   pref
# 2010-04-10  kagawa_miki@example.com      F   28  1991-06-14  광주광역시
# (None, (1, 8))

# %%
# 조건 2개
# 회원들중 남성|여성, 가입기간이 40일 이상(>=)된 고객 회원만 추출하시오 : 실습
temp = cus[(cus.gender == 'M')&(cus.membership_period >= 40)]

display(temp.sample(2)), temp.shape
# Out:
#     customer_id   name class gender  start_date end_date campaign_id  \
# 224    TS085215  XXXXX   C03      M  2015-08-01      NaN         CA1
# 196    GD687485  XXXXX   C01      M  2015-08-01      NaN         CA1
#
#      is_deleted class_name  price campaign_name      mean  median  max  min  \
# 224           0       2_야간   6000          2_일반  5.250000     5.0    7    2
# 196           0       0_종일  10500          2_일반  4.916667     5.0    7    2
#
#      routine_flg   calc_date  membership_period
# 224            1  2019-04-30                 44
# 196            1  2019-04-30                 44
# (None, (265, 18))

# %% [markdown]
# # 데이터 삭제

# %% [markdown]
# - del
#   - 파이썬 지원, 메모리 제거, 완전 삭제
#
# - df의 drop
#   - 원본 유지(**inplace** 매개변수가 False인 경우)
#     - DataFrame에서 많은 함수 => 원본 조작하는 느낌 함수들 다수 존재 => 반환값이 DF이면 사본, 반환값이 없으면 원본조작
#     - 명시적으로 설정 옵션 inplace
#       - True : 원본수정, 반환값 x
#       - False : 원본유지, 반환값 o
#   - drop() : 옵셥 여부에 따라 반환값 다름
#     - inplace 상황에 따라 다름
#       - False : 특정 조건에 일치하는 데이터만 추출(특정 컬럼, 데이터를 삭제하고 추출)
#       - True : 원본 수정하고 df 반환

# %%
# cus에서 'end_date'컬럼을 제외(배제)하고 나머지 전체 df 반환
# axis=0 => 1차원 대상 => 가로방향 드롭
# axis=1 => 2차원 대상 => 세로방향 드롭

# ((2953, 18) => (2953, 17))
cus.drop(['end_date'], axis=1).shape, cus.shape
# Out:
# ((2953, 17), (2953, 18))

# %%
# 원본 조작, 위의 요구사항 동일하게 구성
cus.drop(['end_date'], axis=1, inplace=True)

# %%
# 원본 수정됨
cus.shape
# Out:
# (2953, 17)

# %%
# del 사용
del cus['name']

cus.shape
# Out:
# (2953, 16)

# %% [markdown]
# # (*)파생변수

# %% [markdown]
# - 컬럼 추가
#   - dict에서 데이터 추가하는 방식과 유사
#   ```
#     # 사전에 원본에 대해 사본 작업 후, loc계열 사용 이후 적용해야 경고 메세지가 없음
#     df['컬럼명'] = 데이터(df 데이터수와 동일)
#   ```

# %%
df.head(1)
# Out:
#            customer_id customer_name registration_date  \
# 2010-01-01    IK152942           김서준   2019-01-01 0:25
#
#                                   email gender  age       birth   pref
# 2010-01-01  hirata_yuujirou@example.com      M   29  1990-06-10  대전광역시

# %% [markdown]
# - 요구사항 mz세대 체크하는 용도
#   - 컬럼명 : is_mz ( mz : 1985~2009)
#     - o(old) : ~ 1969 <- 가정
#     - x : 1970 ~ 1984
#     - m : 1985 ~ 1994
#     - z : 1995 ~ 2009
#     - 알파('a'lpha) : 2010 ~
#
# - 작업
#   - 데이터 업데이트
#     - 나이 컬럼 사용 언데이트 -> 확인(현재낧짜 - 생년월일:계산)
#   - 파생변수 생성
#     - is_mz

# %%
df.dtypes
# Out:
# customer_id          object
# customer_name        object
# registration_date    object
# email                object
# gender               object
# age                   int64
# birth                object
# pref                 object
# dtype: object

# %%
day = '1990-06-10'
# 위의 문자열에서 1990을 추출하시오
day[:4]

# iz_mz : 참이면 1, 거짓이면 0
# df.birth의 데이터들을 '하나씩 접근'해서, day[:4] 잘라서, 정수 변환, 2025 - 1990 연산->나이
# 1985년 이후는 mz, 아니면 not mz => 추출한 년도값 < 1985

# 파이썬 => map()
# pandas => apply(), str, ...
# Out:
# '1990'

# %%
# age 컬럼을 2025년 기준으로 업데이트 수행
# 2025를 알아서 계산해서 세팅(업그레이드)

# Series
# x : '1990-06-10', '1990-01-01', '1995-06-10', ...
# 연나이 : 2025 - yyyy
# df['컬럼명'] = 데이터(df 데이터수와 동일)
df['age'] = df.birth.apply(lambda x:2025-int(x[:4]))

# is_mz, 알파세대 데이터는 없다는 전제하에 진행
# is_ma, 참이면 1, 거짓이면 0 <= 처리(실습), 이분법, 값세팅 => 상항연산자
df['is_mz'] = df['age'] <= 40 # True or False

# apply() 사용
df['is_mz'] = df.is_mz.apply(lambda x:1 if x else 0)

display(df.is_mz), df.shape
# Out:
# 2010-01-01    1
# 2010-01-02    1
# 2010-01-03    0
# 2010-01-04    0
# 2010-01-05    0
#              ..
# 2023-09-05    0
# 2023-09-06    1
# 2023-09-07    0
# 2023-09-08    0
# 2023-09-09    1
# Freq: D, Name: is_mz, Length: 5000, dtype: int64
# (None, (5000, 9))

# %% [markdown]
# # 고급기능

# %% [markdown]
# ## 집계(groupby)
#
# - '범주형'(명목형, 순서형), 수치형(이산형) 대상이 됨

# %%
df.head(1)
# Out:
#            customer_id customer_name registration_date  \
# 2010-01-01    IK152942           김서준   2019-01-01 0:25
#
#                                   email gender  age       birth   pref  is_mz
# 2010-01-01  hirata_yuujirou@example.com      M   35  1990-06-10  대전광역시      1

# %% [markdown]
# - 기준 컬럼 1개 이용
#   - 해당 컬럼이 인덱스로 배치
#     - 고유한값 배치
#   - 나머진 데이터를 이를 기준을 그룹화

# %%
# is_mz 기준 집계 -> 고객을 특정 기준으로 세분화 -> .... -> 마케팅, 전략 수립
df.groupby(['is_mz']).count()
# Out:
#        customer_id  customer_name  registration_date  email  gender   age  \
# is_mz
# 0             3850           3850               3850   3850    3850  3850
# 1             1150           1150               1150   1150    1150  1150
#
#        birth  pref
# is_mz
# 0       3850  3850
# 1       1150  1150

# %%
# 모든 컬럼의 값이 동일(카운트로 계산) -> 특정 컬럼 선택 표현
temp = df.groupby(['is_mz']).count()[['age']]
temp.columns = ['고객수']
temp
# Out:
#         고객수
# is_mz
# 0      3850
# 1      1150

# %%
# 실습 gender 컬럼을 이용하여 집계하시오 (카운트)
temp = df.groupby(['gender']).count()[['age']]
temp.columns = ['성별']
temp
# Out:
#           성별
# gender
# F       2485
# M       2515

# %% [markdown]
# - 기준 컬럼 2개 사용(2개이상 포함)
#   - 결과물에 레벨이 발생함
#     - 인덱스 내에 단계가 발생
#     - is_mz가 1일때 gender F or M 구분

# %%
temp = df.groupby(['is_mz','gender']).count()[['age']]
temp.columns = ['고객수']
temp
# 해석
# mz 여부에 상관없이 남여 비율이 거의 일정하다 (5:5)
# 머신러닝 등 에서 데이터를 나눠서 학습진행시, 남녀비율을 동일하게, mz비율을 동일하게 구성 -> '층화'

# 데이터가 천만개, 1회 학습할때 100개 사용 -> 무작위로 구성한 100개의 데이터내에
# 남녀비율, mz비율이 전체 데이터에 비율과 동일하게 구성되어야 한다
# Out:
#                고객수
# is_mz gender
# 0     F       1910
#       M       1940
# 1     F        575
#       M        575

# %% [markdown]
# - 집계시 적용할 함수
#   - 집계를 통해서 데이터가 모였다
#   - 이 데이터들을 어떻게 계산(합계, 평균, 표준편차, 분산, 정규화 처리,....)
#   - agg()

# %%
cus.head(1)
# Out:
#   customer_id class gender  start_date campaign_id  is_deleted class_name  \
# 0    OA832399   C01      F  2015-05-01         CA1           0       0_종일
#
#    price campaign_name      mean  median  max  min  routine_flg   calc_date  \
# 0  10500          2_일반  4.833333     5.0    8    2            1  2019-04-30
#
#    membership_period
# 0                 47

# %%
# 데이터 2953개
cus.shape
# Out:
# (2953, 16)

# %%
# 공유한 고객 아이디 개수도 고객별로 1개
len(cus.customer_id.unique()) # 고객별로 1개
# Out:
# 2953

# %%
cus.groupby('gender').agg({
    # 특정 컬럼을 집계 결과로 보고 싶고, 그 집계 내용도 상이하게 표현
    'is_deleted':'count',      # 탈퇴여부는 카운트로만 표기, 탈퇴자 비율 x
    # 변수 2개 집계를 통해서 탈퇴자 비율, 수를 표현 적절할듯 => 학습 정리때 시
    'price':'sum',             # 그룹의 총 구매액
    'membership_period':'mean' # 그룹별 평균 맴버쉽 기간
})
# Out:
#         is_deleted     price  membership_period
# gender
# F             1400  11904000          23.372857
# M             1553  13356000          23.373471

# %% [markdown]
# ## 피벗(데이터내 숨겨진 의미 추출,파악)
#
# - '범주형'(명목형, 순서형), 수치형(이산형) 대상이 됨

# %%
df = pd.read_excel('/content/drive/MyDrive/2. 데이터분석/data/sales.xlsx')

# 영업 데이터(소량, 영업부-)
df
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 12   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# 13   307599   Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 14   688981                   Keeling LLC     Wendy Yule  Fred Anderson
# 15   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
# 16   729833                     Koepp Ltd     Wendy Yule  Fred Anderson
#
#         Product  Quantity   Price     Status
# 0           CPU         1   30000  presented
# 1      Software         1   10000  presented
# 2   Maintenance         2    5000    pending
# 3           CPU         1   35000   declined
# 4           CPU         2   65000        won
# 5           CPU         2   40000    pending
# 6      Software         1   10000  presented
# 7   Maintenance         2    5000    pending
# 8           CPU         1   35000   declined
# 9           CPU         2   65000        won
# 10          CPU         1   30000  presented
# 11  Maintenance         1    5000    pending
# 12     Software         1   10000  presented
# 13  Maintenance         3    7000        won
# 14          CPU         5  100000        won
# 15          CPU         2   65000   declined
# 16      Monitor         2    5000  presented

# %%
# random_state : 난수의 씨드를 설정하는 매개변수, 특정값 고정 -> 항상 같은 난수 발생 -> 재현성
df.sample(2, random_state=1)
# Out:
#     Account                          Name           Rep        Manager  \
# 3    737550  Fritsch, Russel and Anderson  Craig Booker   Debra Henley
# 13   307599   Kassulke, Ondricka and Metz    Wendy Yule  Fred Anderson
#
#         Product  Quantity  Price    Status
# 3           CPU         1  35000  declined
# 13  Maintenance         3   7000       won

# %%
# frac=0.5 : 전체 모집합의 50%를 샘플링 하시오(표본추출), 샘플링 개수를 비율로 표현
tmp = df.sample(frac=0.5, random_state=1)

tmp.shape, df.shape, display(tmp)
# Out:
#     Account                          Name            Rep        Manager  \
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 13   307599   Kassulke, Ondricka and Metz     Wendy Yule  Fred Anderson
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
#
#         Product  Quantity  Price     Status
# 3           CPU         1  35000   declined
# 13  Maintenance         3   7000        won
# 7   Maintenance         2   5000    pending
# 2   Maintenance         2   5000    pending
# 6      Software         1  10000  presented
# 10          CPU         1  30000  presented
# 4           CPU         2  65000        won
# 1      Software         1  10000  presented
# ((8, 8), (17, 8), None)

# %%
# 실습 : Rep의 데이터중 고유한 데이터만 출력 -> 5명 확인
df.Rep.unique()

# 피벗의 대상 가능함
# Out:
# array(['Craig Booker', 'Daniel Hilton', 'John Smith', 'Cedric Moss',
#        'Wendy Yule'], dtype=object)

# %%
# 매니저 2명
df.Manager.unique()

# 피벗의 대상 가능함
# Out:
# array(['Debra Henley', 'Fred Anderson'], dtype=object)

# %%
df.info() # Quantity, Price =>
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Account   17 non-null     int64
#  1   Name      17 non-null     object
#  2   Rep       17 non-null     object
#  3   Manager   17 non-null     object
#  4   Product   17 non-null     object
#  5   Quantity  17 non-null     int64
#  6   Price     17 non-null     int64
#  7   Status    17 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 1.2+ KB

# %%
# 인덱스 항목에 'Name' 컬럼 적용 -> 나머지는 알아서 세팅되게 시도(과거에는 문제 x)
# 데이터에 대해 어떤 설정도 없으면 무조건 평균(기본값) 처리로 시도함
# 과거에는 자동처리, 현재는 직접 지정(값에대한 컬럼을)
df_pv = pd.pivot_table(df, index=['Name'], values=['Quantity','Price'])
df_pv

# 사원별로 매출평균, 수량평균 표현
# Out:
#                                  Price  Quantity
# Name
# Barton LLC                     35000.0  1.000000
# Fritsch, Russel and Anderson   35000.0  1.000000
# Herman LLC                     65000.0  2.000000
# Jerde-Hilpert                   5000.0  2.000000
# Kassulke, Ondricka and Metz     7000.0  3.000000
# Keeling LLC                   100000.0  5.000000
# Kiehn-Spinka                   65000.0  2.000000
# Koepp Ltd                      35000.0  2.000000
# Kulas Inc                      25000.0  1.500000
# Purdy-Kunde                    30000.0  1.000000
# Stokes LLC                      7500.0  1.000000
# Trantow-Barrows                15000.0  1.333333

# %%
# 인덱스 레벨 구현
df_pv = df.pivot_table( index=['Manager', 'Rep', 'Name'],
                        values=['Quantity','Price'])
df_pv

# 해석
# Debra Henley가 관리하는 영업1(?)부의 부장 1명, 팀장 3명, 하위에 팀원 각각 2명
# 직원 관리 및 조직 내 서열관계 확인
# Out:
#                                                              Price  Quantity
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson   35000.0  1.000000
#                             Trantow-Barrows                15000.0  1.333333
#               Daniel Hilton Kiehn-Spinka                   65000.0  2.000000
#                             Kulas Inc                      25000.0  1.500000
#               John Smith    Barton LLC                     35000.0  1.000000
#                             Jerde-Hilpert                   5000.0  2.000000
# Fred Anderson Cedric Moss   Herman LLC                     65000.0  2.000000
#                             Purdy-Kunde                    30000.0  1.000000
#                             Stokes LLC                      7500.0  1.000000
#               Wendy Yule    Kassulke, Ondricka and Metz     7000.0  3.000000
#                             Keeling LLC                   100000.0  5.000000
#                             Koepp Ltd                      35000.0  2.000000

# %%
# 조직 기반에서 영업실적 확인
# 수치 처리시 값 Price로 축소
# 해당 그룹의 수치 데이터 평균, 개수, 합산 => groipby:agg, pv => aggfunc:매개변수
df_pv = df.pivot_table( index=['Manager', 'Rep', 'Name'],
                        values=['Price'],
                        aggfunc=['mean',len, 'sum']
                        )
'''
  - Keeling LLC	사원은 한번에 크게 팔았음, 매출 1위
  - Trantow-Barrows	거래 개수가 가장 높다 1위, 총 매출액은 적다 (저가 제품 판매 예측)
  - Jerde-Hilpert	매출 최하위 거래 1번, 5000(단가 하위)
  - ... -> 결과 도달
'''
df_pv
# 해석 추가 : 어떤 사원이 매출이 높은지, 낮은지, ...
# Out:
#                                                               mean   len  \
#                                                              Price Price
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson   35000.0     1
#                             Trantow-Barrows                15000.0     3
#               Daniel Hilton Kiehn-Spinka                   65000.0     1
#                             Kulas Inc                      25000.0     2
#               John Smith    Barton LLC                     35000.0     1
#                             Jerde-Hilpert                   5000.0     1
# Fred Anderson Cedric Moss   Herman LLC                     65000.0     1
#                             Purdy-Kunde                    30000.0     1
#                             Stokes LLC                      7500.0     2
#               Wendy Yule    Kassulke, Ondricka and Metz     7000.0     1
#                             Keeling LLC                   100000.0     1
#                             Koepp Ltd                      35000.0     2
#
#                                                              sum
#                                                            Price
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson   35000
#                             Trantow-Barrows                45000
#               Daniel Hilton Kiehn-Spinka                   65000
#                             Kulas Inc                      50000
#               John Smith    Barton LLC                     35000
#                             Jerde-Hilpert                   5000
# Fred Anderson Cedric Moss   Herman LLC                     65000
#                             Purdy-Kunde                    30000
#                             Stokes LLC                     15000
#               Wendy Yule    Kassulke, Ondricka and Metz     7000
#                             Keeling LLC                   100000
#                             Koepp Ltd                      70000

# %%
# 컬럼지정 -> 판매 제품 노출 -> 결측 관찰됨(팔지 못한 제품 확인)
# 어떤 제품을 어떤 영업인이 잘 파는지?
df_pv = df.pivot_table( index  =['Manager', 'Rep', 'Name'],
                        values =['Price'],
                        aggfunc=['mean', len, 'sum' ],
                        columns=['Product']
                        )

'''
  - Trantow-Barrows 다양한 품목 판매
'''
df_pv
# Out:
#                                                               mean  \
#                                                              Price
# Product                                                        CPU
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson   35000.0
#                             Trantow-Barrows                30000.0
#               Daniel Hilton Kiehn-Spinka                   65000.0
#                             Kulas Inc                      40000.0
#               John Smith    Barton LLC                     35000.0
#                             Jerde-Hilpert                      NaN
# Fred Anderson Cedric Moss   Herman LLC                     65000.0
#                             Purdy-Kunde                    30000.0
#                             Stokes LLC                         NaN
#               Wendy Yule    Kassulke, Ondricka and Metz        NaN
#                             Keeling LLC                   100000.0
#                             Koepp Ltd                      65000.0
#
#                                                                               \
#
# Product                                                  Maintenance Monitor
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson         NaN     NaN
#                             Trantow-Barrows                   5000.0     NaN
#               Daniel Hilton Kiehn-Spinka                         NaN     NaN
#                             Kulas Inc                            NaN     NaN
#               John Smith    Barton LLC                           NaN     NaN
#                             Jerde-Hilpert                     5000.0     NaN
# Fred Anderson Cedric Moss   Herman LLC                           NaN     NaN
#                             Purdy-Kunde                          NaN     NaN
#                             Stokes LLC                        5000.0     NaN
#               Wendy Yule    Kassulke, Ondricka and Metz       7000.0     NaN
#                             Keeling LLC                          NaN     NaN
#                             Koepp Ltd                            NaN  5000.0
#
#                                                                     len  \
#                                                                   Price
# Product                                                  Software   CPU
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson      NaN   1.0
#                             Trantow-Barrows               10000.0   1.0
#               Daniel Hilton Kiehn-Spinka                      NaN   1.0
#                             Kulas Inc                     10000.0   1.0
#               John Smith    Barton LLC                        NaN   1.0
#                             Jerde-Hilpert                     NaN   NaN
# Fred Anderson Cedric Moss   Herman LLC                        NaN   1.0
#                             Purdy-Kunde                       NaN   1.0
#                             Stokes LLC                    10000.0   NaN
#               Wendy Yule    Kassulke, Ondricka and Metz       NaN   NaN
#                             Keeling LLC                       NaN   1.0
#                             Koepp Ltd                         NaN   1.0
#
#                                                                               \
#
# Product                                                  Maintenance Monitor
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson         NaN     NaN
#                             Trantow-Barrows                      1.0     NaN
#               Daniel Hilton Kiehn-Spinka                         NaN     NaN
#                             Kulas Inc                            NaN     NaN
#               John Smith    Barton LLC                           NaN     NaN
#                             Jerde-Hilpert                        1.0     NaN
# Fred Anderson Cedric Moss   Herman LLC                           NaN     NaN
#                             Purdy-Kunde                          NaN     NaN
#                             Stokes LLC                           1.0     NaN
#               Wendy Yule    Kassulke, Ondricka and Metz          1.0     NaN
#                             Keeling LLC                          NaN     NaN
#                             Koepp Ltd                            NaN     1.0
#
#                                                                         sum  \
#                                                                       Price
# Product                                                  Software       CPU
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson      NaN   35000.0
#                             Trantow-Barrows                   1.0   30000.0
#               Daniel Hilton Kiehn-Spinka                      NaN   65000.0
#                             Kulas Inc                         1.0   40000.0
#               John Smith    Barton LLC                        NaN   35000.0
#                             Jerde-Hilpert                     NaN       NaN
# Fred Anderson Cedric Moss   Herman LLC                        NaN   65000.0
#                             Purdy-Kunde                       NaN   30000.0
#                             Stokes LLC                        1.0       NaN
#               Wendy Yule    Kassulke, Ondricka and Metz       NaN       NaN
#                             Keeling LLC                       NaN  100000.0
#                             Koepp Ltd                         NaN   65000.0
#
#                                                                               \
#
# Product                                                  Maintenance Monitor
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson         NaN     NaN
#                             Trantow-Barrows                   5000.0     NaN
#               Daniel Hilton Kiehn-Spinka                         NaN     NaN
#                             Kulas Inc                            NaN     NaN
#               John Smith    Barton LLC                           NaN     NaN
#                             Jerde-Hilpert                     5000.0     NaN
# Fred Anderson Cedric Moss   Herman LLC                           NaN     NaN
#                             Purdy-Kunde                          NaN     NaN
#                             Stokes LLC                        5000.0     NaN
#               Wendy Yule    Kassulke, Ondricka and Metz       7000.0     NaN
#                             Keeling LLC                          NaN     NaN
#                             Koepp Ltd                            NaN  5000.0
#
#
#
# Product                                                  Software
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson      NaN
#                             Trantow-Barrows               10000.0
#               Daniel Hilton Kiehn-Spinka                      NaN
#                             Kulas Inc                     10000.0
#               John Smith    Barton LLC                        NaN
#                             Jerde-Hilpert                     NaN
# Fred Anderson Cedric Moss   Herman LLC                        NaN
#                             Purdy-Kunde                       NaN
#                             Stokes LLC                    10000.0
#               Wendy Yule    Kassulke, Ondricka and Metz       NaN
#                             Keeling LLC                       NaN
#                             Koepp Ltd                         NaN

# %%
# pv를 만들때 적용
df_pv = df.pivot_table( index  =['Manager', 'Rep', 'Name'],
                        values =['Price'],
                        aggfunc=['mean', len, 'sum' ],
                        columns=['Product'],
                        fill_value=0 # 기본값으로 정수타입으로 설정
                        )
df_pv
# Out:
#                                                               mean  \
#                                                              Price
# Product                                                        CPU
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson   35000.0
#                             Trantow-Barrows                30000.0
#               Daniel Hilton Kiehn-Spinka                   65000.0
#                             Kulas Inc                      40000.0
#               John Smith    Barton LLC                     35000.0
#                             Jerde-Hilpert                      0.0
# Fred Anderson Cedric Moss   Herman LLC                     65000.0
#                             Purdy-Kunde                    30000.0
#                             Stokes LLC                         0.0
#               Wendy Yule    Kassulke, Ondricka and Metz        0.0
#                             Keeling LLC                   100000.0
#                             Koepp Ltd                      65000.0
#
#                                                                               \
#
# Product                                                  Maintenance Monitor
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson         0.0     0.0
#                             Trantow-Barrows                   5000.0     0.0
#               Daniel Hilton Kiehn-Spinka                         0.0     0.0
#                             Kulas Inc                            0.0     0.0
#               John Smith    Barton LLC                           0.0     0.0
#                             Jerde-Hilpert                     5000.0     0.0
# Fred Anderson Cedric Moss   Herman LLC                           0.0     0.0
#                             Purdy-Kunde                          0.0     0.0
#                             Stokes LLC                        5000.0     0.0
#               Wendy Yule    Kassulke, Ondricka and Metz       7000.0     0.0
#                             Keeling LLC                          0.0     0.0
#                             Koepp Ltd                            0.0  5000.0
#
#                                                                     len  \
#                                                                   Price
# Product                                                  Software   CPU
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson      0.0     1
#                             Trantow-Barrows               10000.0     1
#               Daniel Hilton Kiehn-Spinka                      0.0     1
#                             Kulas Inc                     10000.0     1
#               John Smith    Barton LLC                        0.0     1
#                             Jerde-Hilpert                     0.0     0
# Fred Anderson Cedric Moss   Herman LLC                        0.0     1
#                             Purdy-Kunde                       0.0     1
#                             Stokes LLC                    10000.0     0
#               Wendy Yule    Kassulke, Ondricka and Metz       0.0     0
#                             Keeling LLC                       0.0     1
#                             Koepp Ltd                         0.0     1
#
#                                                                               \
#
# Product                                                  Maintenance Monitor
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson           0       0
#                             Trantow-Barrows                        1       0
#               Daniel Hilton Kiehn-Spinka                           0       0
#                             Kulas Inc                              0       0
#               John Smith    Barton LLC                             0       0
#                             Jerde-Hilpert                          1       0
# Fred Anderson Cedric Moss   Herman LLC                             0       0
#                             Purdy-Kunde                            0       0
#                             Stokes LLC                             1       0
#               Wendy Yule    Kassulke, Ondricka and Metz            1       0
#                             Keeling LLC                            0       0
#                             Koepp Ltd                              0       1
#
#                                                                       sum  \
#                                                                     Price
# Product                                                  Software     CPU
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson        0   35000
#                             Trantow-Barrows                     1   30000
#               Daniel Hilton Kiehn-Spinka                        0   65000
#                             Kulas Inc                           1   40000
#               John Smith    Barton LLC                          0   35000
#                             Jerde-Hilpert                       0       0
# Fred Anderson Cedric Moss   Herman LLC                          0   65000
#                             Purdy-Kunde                         0   30000
#                             Stokes LLC                          1       0
#               Wendy Yule    Kassulke, Ondricka and Metz         0       0
#                             Keeling LLC                         0  100000
#                             Koepp Ltd                           0   65000
#
#                                                                               \
#
# Product                                                  Maintenance Monitor
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson           0       0
#                             Trantow-Barrows                     5000       0
#               Daniel Hilton Kiehn-Spinka                           0       0
#                             Kulas Inc                              0       0
#               John Smith    Barton LLC                             0       0
#                             Jerde-Hilpert                       5000       0
# Fred Anderson Cedric Moss   Herman LLC                             0       0
#                             Purdy-Kunde                            0       0
#                             Stokes LLC                          5000       0
#               Wendy Yule    Kassulke, Ondricka and Metz         7000       0
#                             Keeling LLC                            0       0
#                             Koepp Ltd                              0    5000
#
#
#
# Product                                                  Software
# Manager       Rep           Name
# Debra Henley  Craig Booker  Fritsch, Russel and Anderson        0
#                             Trantow-Barrows                 10000
#               Daniel Hilton Kiehn-Spinka                        0
#                             Kulas Inc                       10000
#               John Smith    Barton LLC                          0
#                             Jerde-Hilpert                       0
# Fred Anderson Cedric Moss   Herman LLC                          0
#                             Purdy-Kunde                         0
#                             Stokes LLC                      10000
#               Wendy Yule    Kassulke, Ondricka and Metz         0
#                             Keeling LLC                         0
#                             Koepp Ltd                           0

# %% [markdown]
# ## 병합 (단순 합치기, 조인)

# %% [markdown]
# - 종류
#   - concat()
#     - 단순합치기
#     - 결측 발생 확률이 높음
#     - n개의 df를 합칠때 사용
#     - 데이터의 컬럼이 동일할 경우 유용
#     - 축의 방향성(axis)
#   - merge()
#     - sql의 join과 유사
#     - 2개의 df을 합칠때
#     - 통상 공통의 컬럼이 존재함
#
#   - 특징
#     - 데이터 획득 후 초기에 발생(데이터가 쪼개져서 전달받은 경우)
#     - 분석 과정에 파생 변수 생성 -> 필요시 합쳐서 처리 : 필요시

# %% [markdown]
# ### 더미데이터

# %%
left_df = pd.DataFrame({
    'key':list("1234"),
    'A'  :list("abcd"),
    'B'  :list("ABCD")
})

right_df = pd.DataFrame({
    'key':list("0123"),
    'C'  :list("wxyz"),
    'D'  :list("WXYZ")
})

display(left_df), display(right_df)
# Out:
#   key  A  B
# 0   1  a  A
# 1   2  b  B
# 2   3  c  C
# 3   4  d  D
#   key  C  D
# 0   0  w  W
# 1   1  x  X
# 2   2  y  Y
# 3   3  z  Z
# (None, None)

# %% [markdown]
# ### merge

# %%
# 2개의 df 대상, 2개의 df에 중복된 컬럼 지정
pd.merge(left_df, right_df, on='key')
# on 값으로 지정된 컬럼 대상, 쌍방이 일치하는 데이터가 존재하는 경우, 해당 데이터만 모은다
# sql inner join
# 결측치가 임의로 발생
# Out:
#   key  A  B  C  D
# 0   1  a  A  x  X
# 1   2  b  B  y  Y
# 2   3  c  C  z  Z

# %%
# 같은 결론
pd.merge(left_df, right_df, on='key', how='inner')
# Out:
#   key  A  B  C  D
# 0   1  a  A  x  X
# 1   2  b  B  y  Y
# 2   3  c  C  z  Z

# %%
# left join
# 왼쪽 df는 유지, 이를 기준으로 오른쪽 병함, 일치되는 key값이 없으면 결측
pd.merge(left_df, right_df, on='key', how='left')

# 왼쪽 df는 변형x, 유지됨
# Out:
#   key  A  B    C    D
# 0   1  a  A    x    X
# 1   2  b  B    y    Y
# 2   3  c  C    z    Z
# 3   4  d  D  NaN  NaN

# %%
# right join : left join의 정반대 작용
pd.merge(left_df, right_df, on='key', how='right')
# Out:
#   key    A    B  C  D
# 0   0  NaN  NaN  w  W
# 1   1    a    A  x  X
# 2   2    b    B  y  Y
# 3   3    c    C  z  Z

# %%
# outer join : 양쪽을 모두 살림 -> 양쪽에서 결측 발생 가능성 있
pd.merge(left_df, right_df, on='key', how='outer')
# Out:
#   key    A    B    C    D
# 0   0  NaN  NaN    w    W
# 1   1    a    A    x    X
# 2   2    b    B    y    Y
# 3   3    c    C    z    Z
# 4   4    d    D  NaN  NaN

# %% [markdown]
# ### concat

# %% [markdown]
# - 단순 합치기
#   - 공통의 컬럼 -> 신경안씀
#   - axis 축의 방향
#   - n개를 합침
# - 용도
#   - 동일한 데이터가 n개로 쪼개져 있을때 유용

# %%
# 연속형 자료구조(통상 리스트에 df 모아두고 합치기)
# axis : 동일한 컬럼의 데이터라면 수직으로 늘리는게 유용 -> 데이터가 늘어남, axis=0, 기본값
# axis : 동일한 컬럼이 없다면 수평방향이 유용 -> 피처가 늘어남, axis=1
pd.concat([left_df, right_df], axis=0)
# Out:
#   key    A    B    C    D
# 0   1    a    A  NaN  NaN
# 1   2    b    B  NaN  NaN
# 2   3    c    C  NaN  NaN
# 3   4    d    D  NaN  NaN
# 0   0  NaN  NaN    w    W
# 1   1  NaN  NaN    x    X
# 2   2  NaN  NaN    y    Y
# 3   3  NaN  NaN    z    Z

# %%
pd.concat([left_df, right_df], axis=1)
# Out:
#   key  A  B key  C  D
# 0   1  a  A   0  w  W
# 1   2  b  B   1  x  X
# 2   3  c  C   2  y  Y
# 3   4  d  D   3  z  Z

# %%
# 중복 등장 가능
pd.concat([left_df, right_df, left_df])
# Out:
#   key    A    B    C    D
# 0   1    a    A  NaN  NaN
# 1   2    b    B  NaN  NaN
# 2   3    c    C  NaN  NaN
# 3   4    d    D  NaN  NaN
# 0   0  NaN  NaN    w    W
# 1   1  NaN  NaN    x    X
# 2   2  NaN  NaN    y    Y
# 3   3  NaN  NaN    z    Z
# 0   1    a    A  NaN  NaN
# 1   2    b    B  NaN  NaN
# 2   3    c    C  NaN  NaN
# 3   4    d    D  NaN  NaN

# %% [markdown]
# # 기타(전처리)

# %%
# 더미데이터
tmp = pd.DataFrame({
    'A':[1, 2, np.nan, np.nan],
    'B':[4, 5, 3, 3],
    'C':[3, 1, np.nan, np.nan]
})
tmp

# 인덱스 2, 3번 데이터는 동일함(중복데이터)
# Out:
#      A  B    C
# 0  1.0  4  3.0
# 1  2.0  5  1.0
# 2  NaN  3  NaN
# 3  NaN  3  NaN

# %% [markdown]
# ## 중복제거

# %%
tmp.drop_duplicates(inplace=True) # 원본반영
# tmp.drop_duplicates() # 중복 제거 = 사본 반환

tmp
# Out:
#      A  B    C
# 0  1.0  4  3.0
# 1  2.0  5  1.0
# 2  NaN  3  NaN

# %% [markdown]
# ## 결측처리

# %% [markdown]
# - 삭제
#   - 해당 데이터가 없어도 전체 데이터에 영향x (판단이 작용)
#   - 대량의 로그 데이터
#
# - 결측치 그대로 데이터로 인정, 사용
#
# - 특정값 초기화 -> 보정
#   - 0과 같은 특정값 부여
#   - 이전 데이터의 값 적용
#     - 시계열 데이터에 줄 많이 등장
#       - 시간의 흐름에 따라 설정되는 데이터(주식/주가/코인/환율:금융데이터, IOT:센서데이터, 스마트팩토리, ...)
#   - 이전/다음 데이터의 평균값 적용

# %%
tmp.info()
# 결측치 포함한 컬럼 A,C 컬럼, 카운트 수가 전체 엔트리 수와 다름
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       2 non-null      float64
#  1   B       3 non-null      int64
#  2   C       2 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 96.0 bytes

# %%
# 결측 여부 판단 -> 데이터건건 확인
tmp.isna() # True => 결측
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# 2   True  False   True

# %%
tmp.isnull()
# Out:
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# 2   True  False   True

# %%
tmp.isnull().sum()
# 특정 컬럼에서 결측이 몇개 발생했는지 체크
# True:1, Fales:0
# Out:
# A    1
# B    0
# C    1
# dtype: int64

# %% [markdown]
# ## 컬럼명변경

# %%
# 서울시산업체현황.txt => df로 로드 처리, 구분자 sep='/t', header=2
data_path = '/content/drive/MyDrive/2. 데이터분석/data/서울시산업체현황.txt'
df = pd.read_csv(data_path, sep='\t', header=2)
df
# Out:
#        기간  자치구     동     사업체수    여성대표자          계          남          여  \
# 0    2018   합계    합계  823,385  279,711  5,210,936  2,878,227  2,332,709
# 1    2018  종로구    소계   39,952   13,442    265,017    152,717    112,300
# 2    2018  종로구   사직동    3,541    1,191     49,536     28,658     20,878
# 3    2018  종로구   삼청동      712      324      4,577      2,193      2,384
# 4    2018  종로구   부암동      565      240      3,609      1,706      1,903
# ..    ...  ...   ...      ...      ...        ...        ...        ...
# 445  2018  강동구  둔촌1동       19        4        341        230        111
# 446  2018  강동구  둔촌2동    1,601      567      9,718      4,800      4,918
# 447  2018  강동구  암사1동    1,916      677      5,756      2,957      2,799
# 448  2018  강동구  천호2동    3,736    1,500     14,933      7,104      7,829
# 449  2018  강동구    길동    5,172    1,447     19,657     10,514      9,143
#
#     사업체수.1 종사자수  ... 사업체수.15  종사자수.14 사업체수.16  종사자수.15 사업체수.17  종사자수.16  \
# 0       30  462  ...   1,282  140,121  35,377  346,219  28,824  378,366
# 1        3   17  ...      89   15,658     850   13,504     744   15,888
# 2        1   14  ...      19    6,312      86      967     103      870
# 3        -    -  ...       4    1,204      14      260       7       30
# 4        -    -  ...       3       59      40    1,424      15      148
# ..     ...  ...  ...     ...      ...     ...      ...     ...      ...
# 445      -    -  ...       2        8       2      158       -        -
# 446      -    -  ...       2       69      84      575      60    3,122
# 447      -    -  ...       2       31      68      271      68      962
# 448      -    -  ...       3      102      98      604     159    1,626
# 449      -    -  ...       6      277     143      871     163    3,280
#
#     사업체수.18 종사자수.17 사업체수.19  종사자수.18
# 0    23,025  91,104  69,694  191,423
# 1       909   6,227   2,448    7,672
# 2        95   1,544     252      843
# 3        17     175      24      209
# 4        16      40      83      362
# ..      ...     ...     ...      ...
# 445       -       -       3        5
# 446      55     124     219      342
# 447      61     149     236      404
# 448     116     487     345      877
# 449     135     385     428      938
#
# [450 rows x 46 columns]

# %%
# 컬럼이 너무 많으면 T로 축 변경하여 수직으로 확인
# df.head(2).T
df.head(2)
# Out:
#      기간  자치구   동     사업체수    여성대표자          계          남          여 사업체수.1  \
# 0  2018   합계  합계  823,385  279,711  5,210,936  2,878,227  2,332,709     30
# 1  2018  종로구  소계   39,952   13,442    265,017    152,717    112,300      3
#
#   종사자수  ... 사업체수.15  종사자수.14 사업체수.16  종사자수.15 사업체수.17  종사자수.16 사업체수.18  \
# 0  462  ...   1,282  140,121  35,377  346,219  28,824  378,366  23,025
# 1   17  ...      89   15,658     850   13,504     744   15,888     909
#
#   종사자수.17 사업체수.19  종사자수.18
# 0  91,104  69,694  191,423
# 1   6,227   2,448    7,672
#
# [2 rows x 46 columns]

# %% [markdown]
# - 컬럼 변경 전략
#   - df 구성 후 초반에 수행
#     - 전체 변경
#       - df.columns = ['','',...]
#     - 부분적, 개별변경
#       - dict로 매칭하여 변경
#         {
#           '원본이름':'신규이름'
#         }
# - 적용
#   - 컬럼명이 데이터를 온전하게 대변하지 못할때
#   - 공백이 있거나, 구성이 적절하지 못하다고 판단할때

# %%
# 부분 변경
df.rename(columns={
    # 매칭정보
    '계':'총계',
    '남':"총계-남",
    '여':"총계-여"
},inplace=True) # 원본반영

df.head(1)
# Out:
#      기간 자치구   동     사업체수    여성대표자         총계       총계-남       총계-여 사업체수.1  \
# 0  2018  합계  합계  823,385  279,711  5,210,936  2,878,227  2,332,709     30
#
#   종사자수  ... 사업체수.15  종사자수.14 사업체수.16  종사자수.15 사업체수.17  종사자수.16 사업체수.18  \
# 0  462  ...   1,282  140,121  35,377  346,219  28,824  378,366  23,025
#
#   종사자수.17 사업체수.19  종사자수.18
# 0  91,104  69,694  191,423
#
# [1 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['기간', '자치구', '동', '사업체수', '여성대표자', '계', '남', '여', '사업체수.1', '종사자수',
#        '사업체수.2', '종사자수.1', '사업체수.3', '종사자수.2', '사업체수.4', '종사자수.3', '사업체수.5',
#        '종사자수.4', '사업체수.6', '종사자수.5', '사업체수.7', '종사자수.6', '사업체수.8', '종사자수.7',
#        '사업체수.9', '종사자수.8', '사업체수.10', '종사자수.9', '사업체수.11', '종사자수.10',
#        '사업체수.12', '종사자수.11', '사업체수.13', '종사자수.12', '사업체수.14', '종사자수.13',
#        '사업체수.15', '종사자수.14', '사업체수.16', '종사자수.15', '사업체수.17', '종사자수.16',
#        '사업체수.18', '종사자수.17', '사업체수.19', '종사자수.18'],
#       dtype='object')

# %% [markdown]
# ## apply(), str

# %% [markdown]
# - 데이터를 하나씩 접근해서, 전처리 수행 -> 다시 데이터로 세팅(수정), 파생변수 생성

# %%
# 총계 추출
temp = df['총계'].copy(deep=True)
temp.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 450 entries, 0 to 449
# Series name: 총계
# Non-Null Count  Dtype
# --------------  -----
# 450 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB

# %%
# 데이터는 수치이지만, ',' 때문에 문자열로 처리되었음
temp.sample(5)
# Out:
# 373    15,578
# 27      3,830
# 337     9,011
# 441     7,397
# 318    11,110
# Name: 총계, dtype: object

# %%
# %%time
# 데이터에 ,를 제거하여 정수로 처리하시오
# apply() 사용, 람다함수 가급적 사용
temp.apply(lambda x: int(x.replace(',','')))
# Out:
# CPU times: user 505 µs, sys: 67 µs, total: 572 µs
# Wall time: 564 µs
# 0      5210936
# 1       265017
# 2        49536
# 3         4577
# 4         3609
#         ...
# 445        341
# 446       9718
# 447       5756
# 448      14933
# 449      19657
# Name: 총계, Length: 450, dtype: int64

# %%
# %%time
# str 사용, 문자열 데이터에 한해서 처리가능
temp.str.replace(',','').astype(int)
# Out:
# CPU times: user 1.7 ms, sys: 85 µs, total: 1.79 ms
# Wall time: 1.8 ms
# 0      5210936
# 1       265017
# 2        49536
# 3         4577
# 4         3609
#         ...
# 445        341
# 446       9718
# 447       5756
# 448      14933
# 449      19657
# Name: 총계, Length: 450, dtype: int64
